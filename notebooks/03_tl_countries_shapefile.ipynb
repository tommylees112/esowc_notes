# %%
import geopandas as gpd
from pathlib import Path
import xarray as xr

import cdsapi
import matplotlib.pyplot as plt
import cartopy.crs as crs
import xarray as xr

# %matplotlib inline
plt.rcParams['figure.figsize'] = 12, 6

# %%
# Set working directory as project root
import os
if os.getcwd().split('/')[-1] != "ESoWC_dummy":
    os.chdir('..')
    
assert os.getcwd().split('/')[-1] == "ESoWC_dummy", f"Working directory should be the root (), currently: {os.getcwd()}"
print("Current Directory: ",os.getcwd())
# Out:
# Current Directory:  /Users/tommylees/github/ESoWC_dummy

# %%
import subprocess

data_dir = Path('./data')

# download the natural earth data for country shapefiles
if not (data_dir/"countries_shp").exists():
    process = subprocess.Popen("chmod +x example_scripts/download_country_shp.sh".split(), stdout=subprocess.PIPE)
    subprocess.call("example_scripts/download_country_shp.sh", shell=True)

# %%
# open the shapefile and plot
gdf = gpd.read_file(data_dir/"countries_shp"/"ne_50m_admin_0_countries.shp")
gdf.plot();
gdf.columns
# Out:
# Index(['featurecla', 'scalerank', 'LABELRANK', 'SOVEREIGNT', 'SOV_A3',
#        'ADM0_DIF', 'LEVEL', 'TYPE', 'ADMIN', 'ADM0_A3', 'GEOU_DIF', 'GEOUNIT',
#        'GU_A3', 'SU_DIF', 'SUBUNIT', 'SU_A3', 'BRK_DIFF', 'NAME', 'NAME_LONG',
#        'BRK_A3', 'BRK_NAME', 'BRK_GROUP', 'ABBREV', 'POSTAL', 'FORMAL_EN',
#        'FORMAL_FR', 'NAME_CIAWF', 'NOTE_ADM0', 'NOTE_BRK', 'NAME_SORT',
#        'NAME_ALT', 'MAPCOLOR7', 'MAPCOLOR8', 'MAPCOLOR9', 'MAPCOLOR13',
#        'POP_EST', 'POP_RANK', 'GDP_MD_EST', 'POP_YEAR', 'LASTCENSUS',
#        'GDP_YEAR', 'ECONOMY', 'INCOME_GRP', 'WIKIPEDIA', 'FIPS_10_', 'ISO_A2',
#        'ISO_A3', 'ISO_A3_EH', 'ISO_N3', 'UN_A3', 'WB_A2', 'WB_A3', 'WOE_ID',
#        'WOE_ID_EH', 'WOE_NOTE', 'ADM0_A3_IS', 'ADM0_A3_US', 'ADM0_A3_UN',
#        'ADM0_A3_WB', 'CONTINENT', 'REGION_UN', 'SUBREGION', 'REGION_WB',
#        'NAME_LEN', 'LONG_LEN', 'ABBREV_LEN', 'TINY', 'HOMEPART', 'MIN_ZOOM',
# ...

# %%
gdf[gdf.SUBREGION == "Eastern Africa"].plot()
